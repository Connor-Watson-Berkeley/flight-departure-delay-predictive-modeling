# %% [markdown]
# # Final Project Phase 2: Team 4_2

# %% [markdown]
# # 1.  Team and Project Meta Information
#
# ### 1.1 Phase Leader
# - **Name:**  Emily Lieske
# - **Role:**
# - **Email:**  emily-lieske@berkeley.edu
#
# ### 1.2 Project Title and Group Number
# - **Title:**  Flight Delay Prediction with Weather-Aware ML Models: Phase 2
# - **Group #:**  4_2

# %% [markdown]
# ### 1.3 Team Members
# <table>
#   <tr>
#     <td align="center" style="padding:12px;">
#       <img src="https://github.com/Connor-Watson-Berkeley/flight-departure-delay-predictive-modeling/blob/main/report-images/emily_lieske.jpeg?raw=true" width="110" style="border-radius:12px; object-fit:cover;">
#       <div style="font-weight:600; margin-top:8px;">Emily Lieske</div>
#       <a href="mailto:emily-lieske@berkeley.edu">emily-lieske@berkeley.edu</a>
#     </td>
#     <td align="center" style="padding:12px;">
#       <img src="https://github.com/Connor-Watson-Berkeley/flight-departure-delay-predictive-modeling/blob/main/report-images/siddharth_manu.jpg?raw=true" width="110" style="border-radius:12px; object-fit:cover;">
#       <div style="font-weight:600; margin-top:8px;">Siddharth Manu</div>
#       <a href="mailto:siddharthmanu@berkeley.edu">siddharthmanu@berkeley.edu</a>
#     </td>
#       </td>
#     <td align="center" style="padding:12px;">
#       <img src="https://github.com/Connor-Watson-Berkeley/flight-departure-delay-predictive-modeling/blob/main/report-images/indri_Adisoemarta.jpg?raw=true" width="110" style="border-radius:12px; object-fit:cover;">
#       <div style="font-weight:600; margin-top:8px;">Indri Adisoemarta</div>
#       <a href="mailto:indri.a@berkeley.edu">indri.a@berkeley.edu</a>
#     </td>
#         </td>
#     <td align="center" style="padding:12px;">
#       <img src="***REMOVED***" width="110" style="border-radius:12px; object-fit:cover;">
#       <div style="font-weight:600; margin-top:8px;">Paul Lin</div>
#       <a href="mailto:paul.lin@berkeley.edu">paul.lin@berkeley.edu</a>
#     </td>
#         </td>
#     <td align="center" style="padding:12px;">
#       <img src="https://github.com/Connor-Watson-Berkeley/flight-departure-delay-predictive-modeling/blob/main/report-images/conner-watson.jpg?raw=true" width="110" style="border-radius:12px; object-fit:cover;">
#       <div style="font-weight:600; margin-top:8px;">Connor Watson</div>
#       <a href="mailto:connorwatson@berkeley.edu">connorwatson@berkeley.edu</a>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ### Credit Assignment for Phase 2
# | **Team Member** | **Tasks & Deliverables** |
# |-----------------|--------------------------|
# | **Emily Lieske** |  |
# | **Indri Adisoemarta** |  |
# | **Siddharth Manu** |  |
# | **Connor Watson** |  |
# | **Paul Lin** | |

# %% [markdown]
# ## 2. 📄 Project Abstract
#
# **Guidelines:** 2–3 concise paragraphs.
#
# 1. **Business Problem & Data Sources** – Summarize the context and purpose.
# 2. **Baseline Model** – Describe baseline choice, rationale, and baseline metric.
# 3. **Key Features & Next Steps** – Mention top features and future direction.
#
# *(Keep this section concise, clear, and polished.)*
#
# ---
#
# ## 3. Project Description (Data and Tasks)
#
# ### 3.1 Data Description
# - Data source(s) and formats (CSV, API, SQL, etc.)
# - Data dictionary (feature name, description, data type)
# - Dataset size (rows, columns, train/validation/test splits)
#
# ### 3.2 Task Description
# - Define prediction or classification task.
# - Explain business relevance and motivation.
# - Provide workflow diagram or summary of approach.

# %%
```mermaid
flowchart LR
A[Raw Data] --> B[Data Cleaning]
B --> C[EDA]
C --> D[Feature Engineering]
D --> E[Modeling]
E --> F[Evaluation]
F --> G[Results & Discussion]

# %% [markdown]
# ## 2. Project Abstract
#
# **Guidelines:** 2–3 concise paragraphs.
#
# 1. **Business Problem & Data Sources** – Summarize the context and purpose.
# 2. **Baseline Model** – Describe baseline choice, rationale, and baseline metric.
# 3. **Key Features & Next Steps** – Mention top features and future direction.
#
# *(Keep this section concise, clear, and polished.)*
#
# ---
#
# ## 3. Project Description (Data and Tasks)
#
# ### 3.1 Data Description
# - Data source(s) and formats (CSV, API, SQL, etc.)
# - Data dictionary (feature name, description, data type)
# - Dataset size (rows, columns, train/validation/test splits)
#
# ### 3.2 Task Description
# - Define prediction or classification task.
# - Explain business relevance and motivation.
# - Provide workflow diagram or summary of approach.
#
# ```mermaid
# flowchart LR
# A[Raw Data] --> B[Data Cleaning]
# B --> C[EDA]
# C --> D[Feature Engineering]
# D --> E[Modeling]
# E --> F[Evaluation]
# F --> G[Results & Discussion]
# ```
#
# ---
#
# ## 4. Exploratory Data Analysis (EDA)
#
# ### 4.1 Dataset Summary
# - Brief English description of each table.
#
# ### 4.2 Data Dictionary and Summary Statistics
# *(Add or import table summary using Pandas profiling if available)*
#
# ### 4.3 Missing Values and Correlations
# - Discuss missing values, correlation insights, and key takeaways.
#
# ### 4.4 Visualizations
# Include:
# - Distribution plots (input/target)
# - Correlation heatmap
# - Pairplots / boxplots / scatter plots
# - Missing value visual summary
# - Optional: Geo or time-series visualizations
#
# > Ensure all visuals have clear **titles**, **axis labels with units**, and **legends**.
#
# ---
#
# ## 5. Modeling Pipelines
#
# ### 5.1 Pipeline Overview
# Describe and visualize your modeling pipeline(s).
#
# ```mermaid
# flowchart TD
# A[Feature Engineering] --> B[Model Training]
# B --> C[Evaluation]
# C --> D[Model Selection]
# D --> E[Deployment Ready Pipeline]
# ```
#
# ### 5.2 Feature Families
#
# | Feature Family | Number of Features | Description |
# |----------------|--------------------|--------------|
# | | | |
#
# ### 5.3 Experimental Details
# - **Loss Function:**
#   *(Include LaTeX equation if applicable)*
# - **Cluster Size:** e.g., 8 CPUs, 32GB RAM
# - **Build Time per Model:**
# - **Number of Experiments Conducted:**
#
# ### 5.4 Experiment Table
#
# | Experiment ID | Pipeline | Features Used | Train Metric | Validation Metric | Test Metric | Notes |
# |----------------|-----------|----------------|---------------|------------------|--------------|-------|
# | 1 | | | | | | |
# | 2 | | | | | | |
#
# ---
#
# ## 6. Results and Discussion of Results
#
# ### 6.1 Results Summary
# Report:
# - Training: first ¾ of one-year dataset
# - Blind Testing: last ¼
#
# ### 6.2 Discussion
# - Compare experiments and metrics.
# - Highlight key findings and lessons learned.
# - Discuss best-performing model and justification.
# - Visualize performance comparisons.
#
# *(Use tables or charts to support claims.)*
#
# ---
#
# ## 7. Conclusion
#
# > ~150 words
#
# - Restate **project focus** and **importance**.
# - Restate **hypothesis** (e.g., “Custom ML pipelines can predict X accurately”).
# - Summarize **main contributions and findings**.
# - Discuss **significance of results**.
# - Outline **next steps** and closing reflections.
#
# ---
#
# ## 8. Updated Credit Assignment Plan
#
# | Team Member | Tasks Completed | Start Date | End Date | Hours Spent | % Contribution |
# |--------------|----------------|-------------|-----------|--------------|----------------|
# | | | | | | |
#
# ---
#
# ## 9. (Optional) Joining the Data — Extra Credit
#
# ### 9.1 Join Steps
# Describe each join operation in words and code.
#
# ### 9.2 Join Statistics
#
# | Table Joined | Rows Before | Rows After | Join Type | Time to Run | Cluster Size |
# |---------------|--------------|-------------|------------|--------------|---------------|
# | | | | | | |
#
# ### 9.3 Notes
# Explain:
# - How joins were validated.
# - Any data challenges or optimizations.
# - Screenshots or diagrams if applicable.
#
# ---
#
# ## 10. In-Class Presentation Checklist
#
# - Title Slide (project name, group number, names, photos)
# - Outline Slide (section headings)
# - Business Problem & Data Summary
# - Key EDA Visuals
# - Modeling Pipeline Overview
# - Results Summary
# - Conclusion & Next Steps
#
# > Make sure slides are clear, visual, and tell a **story**. Use consistent formatting and a logical business flow.
#
# ---
#
# **Total Points: 100 (plus up to 15 extra credit)**
