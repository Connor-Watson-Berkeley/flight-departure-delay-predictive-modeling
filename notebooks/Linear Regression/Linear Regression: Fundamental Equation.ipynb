# %% [markdown]
# # Demo: Model with **Preloaded** Engineered Features

# %%
# Dependencies
import sys
import pandas as pd

# Spark Session (Databricks provides this automatically, but we'll create it explicitly for compatibility)
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()


# Load modules from our Databricks repo
import importlib.util
cv_path = "/Workspace/Shared/Team 4_2/flight-departure-delay-predictive-modeling/notebooks/Cross Validator/cv.py"
spec = importlib.util.spec_from_file_location("cv", cv_path)
cv = importlib.util.module_from_spec(spec)
spec.loader.exec_module(cv)


from pyspark.sql import functions as F
from pyspark.ml.feature import Imputer, StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler, SQLTransformer
from pyspark.ml.regression import LinearRegression, RandomForestRegressor
from pyspark.ml import Pipeline

# %% [markdown]
# ## Run Data Loader

# %%
# Run Data Loader

data_loader = cv.FlightDelayDataLoader(source="OTPW",suffix="_with_graph_and_metamodels")
data_loader.load()  # Must call load() manually when providing dataloader

# %% [markdown]
# ## Define Features
#
# Just include graph features in your numerical_features

# %%
# Categorical features (minimal - only if needed for intercept)
categorical_features = []  # Or just: ['origin', 'dest'] if you want airport fixed effects

# Numerical features - Fundamental Equation Components
numerical_features = [
    # ============================================================================
    # Available Time (Rotation Time) - Time between previous departure and current scheduled departure
    # ============================================================================
    'scheduled_lineage_rotation_time_minutes',      # Scheduled available time
    'safe_lineage_rotation_time_minutes',           # Safe available time (handles data leakage)
    
    # ============================================================================
    # Air Time - Previous flight's actual flight duration
    # ============================================================================
    'prev_flight_scheduled_flight_time_minutes',    # Scheduled air time
    'prev_flight_crs_elapsed_time',                 # Scheduled elapsed time (backup)
    'predicted_prev_flight_air_time_XGB_1',         # Predicted air time (meta-model)
    
    # ============================================================================
    # Turnover Time - Ground operations time (previous arrival to current departure)
    # ============================================================================
    'scheduled_lineage_turnover_time_minutes',      # Scheduled turnover time
    'predicted_prev_flight_turnover_time_XGB_1',    # Predicted turnover time (meta-model)
    
    # ============================================================================
    # Required Time - Air Time + Turnover Time (combined)
    # ============================================================================
    'safe_required_time_prev_flight_minutes',       # Safe required time (air + turnover)
    
    # ============================================================================
    # Total Duration - Rotation Time (Air Time + Turnover Time combined)
    # ============================================================================
    'predicted_prev_flight_total_duration_XGB_1',   # Predicted rotation time (meta-model)
]

# numerical_features = [
#     'safe_lineage_rotation_time_minutes',           # Available Time
#     'predicted_prev_flight_air_time_XGB_1',         # Air Time
#     'predicted_prev_flight_turnover_time_XGB_1',    # Turnover Time
# ]

# %%
imputer = Imputer(
    inputCols=numerical_features,
    outputCols=[f"{col}_IMPUTED" for col in numerical_features],
    strategy="mean"
)

indexer = StringIndexer(
    inputCols=categorical_features,
    outputCols=[f"{col}_INDEX" for col in categorical_features],
    handleInvalid="keep"
)

encoder = OneHotEncoder(
    inputCols=[f"{col}_INDEX" for col in categorical_features],
    outputCols=[f"{col}_VEC" for col in categorical_features]
)

assembler = VectorAssembler(
    inputCols=[f"{col}_VEC" for col in categorical_features] + 
              [f"{col}_IMPUTED" for col in numerical_features],
    outputCol="features",
    handleInvalid="skip"
)

# StandardScaler (required for LinearRegression)
scaler = StandardScaler(
    inputCol="features",
    outputCol="scaled_features",
    withMean=True,
    withStd=True
)

# Linear Regression
lr = LinearRegression(
    featuresCol="scaled_features",
    labelCol="DEP_DELAY",
    regParam=0.0,  # No regularization for baseline
    elasticNetParam=0.0,
    solver="normal"  # For statistical significance measures
)

# Pipeline with graph features and meta-model predictions
lr_pipe = Pipeline(stages=[imputer, indexer, encoder, assembler, scaler, lr])

# %% [markdown]
# ## Run Model

# %%
cv_lr_3m = cv.FlightDelayCV(
    estimator=lr_pipe,
    dataloader = data_loader,
    version="3M"
)
cv_lr_3m.fit()

# %%
cv_lr_3m.evaluate()

# %%
cv_lr_60m = cv.FlightDelayCV(
    estimator=lr_pipe,
    dataloader = data_loader,
    version="60M"
)
cv_lr_60m.fit()

# %%
cv_lr_60m.evaluate()

# %%
cv_lr_60m.evaluate(use_fold_3_val_train=True)
